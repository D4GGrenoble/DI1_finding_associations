# %% [markdown]
# # Grenoble association data
#
# NOTES:
# - RNA column look like it matches the national repository 'id' column
# - Missions column can contain a lot of text!

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./../../data/grenoble/associations.csv', delimiter=';')

# %%
df.head()
# Out:
#      Idtf                          Nom                   Email contact  \
# 0  129042  1,2,3, SCIENCES RHÔNE-ALPES        123sciences.ra@gmail.com
# 1  129895              38EME PARALLELE       parallele38asso@gmail.com
# 2  129512                        38SMS              38sms.fr@gmail.com
# 3  128940                  40 BATTEURS          contact@40batteurs.com
# 4  129543              4L FOUR LIBERTY  christophe.skopinski@gmail.com
#
#                                                 Logo  \
# 0                                                NaN
# 1  https://www.grenoble.fr/uploads/Externe/6b/129...
# 2  https://www.grenoble.fr/uploads/Externe/ee/102...
# 3  https://www.grenoble.fr/uploads/Externe/03/128...
# 4  https://www.grenoble.fr/uploads/Externe/58/105...
#
#                         Informations complémentaires  \
# 0                                                NaN
# 1  page Facebook\r\nhttps://www.facebook.com/38em...
# ...

# %%
df.isnull().sum()
# Out:
# Idtf                               0
# Nom                                0
# Email contact                      0
# Logo                             295
# Informations complémentaires     537
# Site internet                    119
# Nombre d'adhérents                 0
# Nombre d'adhérents à Grenoble      0
# Missions de l'association          0
# Lieu géographique d'activité     142
# Domaine 1                          0
# Domaine 2                        336
# Domaine 3                        488
# Zones géographiques              610
# RNA                               16
# dtype: int64

# %%
for i in df["Missions de l'association"]:
    print(i)
# Out:
# Cette association a pour objectif de former le grand public et principalement les adultes à la démarche scientifique.
# Pour cela, elle propose à ses adhérents :
# - Ateliers manip : 1h30-2h chaque mois, les adhérents viennent découvrir par l'expérience un concept scientifiue fondamental.
# - Ouverture labo : 1 journée par semestre, les adhérents découvrent un laboratoire scientifique grenoblois et le travail des chercheurs.
# - Sorties à thème scientifique : chaque semestre, le groupe visite un lieu scientifique ensemble et avec des animateurs.
# Promouvoir et dynamiser la culture hip-hop dans toutes ces formes artistiques. Les activités comprennent : la mise à disposition de locaux pour la pratique artistique, la création et diffusion artistique, l'organisation d'échanges culturels...
# 38SMS à pour objectif de créer du lien social par l'information.
# Nous communiquons toutes les initiatives positives sur le secteur 6 par mail, sms et sur le site internet www.38sms.fr
# ...

# %%
df.tail()
# Out:
#        Idtf                                                Nom  \
# 771  129907                               WINDOWS OFFICE CLOUD
# 772  129191                     YACHT CLUB GRENOBLE CHARAVINES
# 773  129893                                YAIBA BUJINKAN DOJO
# 774  129536  YANG TSE GRENOBLE, TAI CHI CHUAN DE LA FAMILLE...
# 775  129380                          YUBUKAN KARATE DAUPHINOIS
#
#                      Email contact  \
# 771  contact@windowsofficecloud.fr
# 772     webmaster@intranetycgc.org
# 773       yaiba.bujinkan@gmail.com
# 774            tfarineau@orange.fr
# 775                b.frost@free.fr
#
#                                                   Logo  \
# 771  https://www.grenoble.fr/uploads/Externe/eb/129...
# 772  https://www.grenoble.fr/uploads/Externe/19/129...
# 773  https://www.grenoble.fr/uploads/Externe/9c/129...
# 774                                                NaN
# 775  https://www.grenoble.fr/uploads/Externe/ca/129...
#
# ...

# %%
for i in df["Missions de l'association"].values:
    print(i)
# Out:
# Cette association a pour objectif de former le grand public et principalement les adultes à la démarche scientifique.
# Pour cela, elle propose à ses adhérents :
# - Ateliers manip : 1h30-2h chaque mois, les adhérents viennent découvrir par l'expérience un concept scientifiue fondamental.
# - Ouverture labo : 1 journée par semestre, les adhérents découvrent un laboratoire scientifique grenoblois et le travail des chercheurs.
# - Sorties à thème scientifique : chaque semestre, le groupe visite un lieu scientifique ensemble et avec des animateurs.
# Promouvoir et dynamiser la culture hip-hop dans toutes ces formes artistiques. Les activités comprennent : la mise à disposition de locaux pour la pratique artistique, la création et diffusion artistique, l'organisation d'échanges culturels...
# 38SMS à pour objectif de créer du lien social par l'information.
# Nous communiquons toutes les initiatives positives sur le secteur 6 par mail, sms et sur le site internet www.38sms.fr
# ...

# %%
df.iloc[0]["Missions de l'association"]
# Out:
# "Cette association a pour objectif de former le grand public et principalement les adultes à la démarche scientifique.\r\nPour cela, elle propose à ses adhérents : \r\n- Ateliers manip : 1h30-2h chaque mois, les adhérents viennent découvrir par l'expérience un concept scientifiue fondamental.\r\n- Ouverture labo : 1 journée par semestre, les adhérents découvrent un laboratoire scientifique grenoblois et le travail des chercheurs.\r\n- Sorties à thème scientifique : chaque semestre, le groupe visite un lieu scientifique ensemble et avec des animateurs."

# %%
df.tail()
# Out:
#        Idtf                                                Nom  \
# 771  129907                               WINDOWS OFFICE CLOUD
# 772  129191                     YACHT CLUB GRENOBLE CHARAVINES
# 773  129893                                YAIBA BUJINKAN DOJO
# 774  129536  YANG TSE GRENOBLE, TAI CHI CHUAN DE LA FAMILLE...
# 775  129380                          YUBUKAN KARATE DAUPHINOIS
#
#                      Email contact  \
# 771  contact@windowsofficecloud.fr
# 772     webmaster@intranetycgc.org
# 773       yaiba.bujinkan@gmail.com
# 774            tfarineau@orange.fr
# 775                b.frost@free.fr
#
#                                                   Logo  \
# 771  https://www.grenoble.fr/uploads/Externe/eb/129...
# 772  https://www.grenoble.fr/uploads/Externe/19/129...
# 773  https://www.grenoble.fr/uploads/Externe/9c/129...
# 774                                                NaN
# 775  https://www.grenoble.fr/uploads/Externe/ca/129...
#
# ...
